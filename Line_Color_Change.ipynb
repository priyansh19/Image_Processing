# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as mlp

# %%
# !ls
# Out:
# A.png  B.png  Line_Color_Change.ipynb

# %%
# !rm A.png

# %%
# !ls
# Out:
# B.png  Line_Color_Change.ipynb

# %%
x = cv2.imread("B.png")
x= cv2.cvtColor(x, cv2.COLOR_BGR2RGB)

# %%
x
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
mlp.imshow(x)

# %%
height,width,channel=x.shape
print(height)
print(width)
print(channel)
# Out:
# 600
# 1000
# 3

# %%
white=[255,255,255]
black=[0,0,0]
red=[255,0,0]
blue=[0,0,255]

# %%
for row in range(0,height): 
    for column in range(0,width):
        ch = x[row,column]
        #if any( ch != black ):
         #   x[row,column] = red
        if all( ch != white ):
            x[row,column] = blue

# %%
mlp.imshow(x)
